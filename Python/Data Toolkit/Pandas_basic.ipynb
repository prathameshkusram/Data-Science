# %% [raw]
# PANDAS
# --> Pandas is a fast powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the python programming language
#
# # 2008 by Mckinney
#
# # very useful with structured data(tabular data)

# %%
import pandas as pd
#Read a comma-separated values(csv) files into data frame
df=pd.read_csv("healthcare_dataset.csv")

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
# By default pandas understand the first rows as the column name
pd.read_csv("healthcare_dataset.csv",header=None)# internal integer indexes are provided by pandas for both rows and colums
# Out:
#                       0    1       2           3                  4   \
# 0                   Name  Age  Gender  Blood Type  Medical Condition
# 1          Bobby JacksOn   30    Male          B-             Cancer
# 2           LesLie TErRy   62    Male          A+            Obesity
# 3            DaNnY sMitH   76  Female          A-            Obesity
# 4           andrEw waTtS   28  Female          O+           Diabetes
# ...                  ...  ...     ...         ...                ...
# 55496  eLIZABeTH jaCkSOn   42  Female          O+             Asthma
# 55497         KYle pEREz   61  Female         AB-            Obesity
# 55498       HEATher WaNG   38  Female          B+       Hypertension
# 55499     JENniFER JOneS   43    Male          O-          Arthritis
# 55500       jAMES GARCiA   53  Female          O+          Arthritis
#
#                       5                 6                             7   \
# ...

# %%
pd.read_csv("healthcare_dataset.csv",skiprows=2)#skip first two rows while reading the data
# Out:
#             LesLie TErRy  62    Male   A+       Obesity  2019-08-20  \
# 0            DaNnY sMitH  76  Female   A-       Obesity  2022-09-22
# 1           andrEw waTtS  28  Female   O+      Diabetes  2020-11-18
# 2          adrIENNE bEll  43  Female  AB+        Cancer  2022-09-19
# 3          EMILY JOHNSOn  36    Male   A+        Asthma  2023-12-20
# 4         edwArD EDWaRDs  21  Female  AB-      Diabetes  2020-11-03
# ...                  ...  ..     ...  ...           ...         ...
# 55493  eLIZABeTH jaCkSOn  42  Female   O+        Asthma  2020-08-16
# 55494         KYle pEREz  61  Female  AB-       Obesity  2020-01-23
# 55495       HEATher WaNG  38  Female   B+  Hypertension  2020-07-13
# 55496     JENniFER JOneS  43    Male   O-     Arthritis  2019-05-25
# 55497       jAMES GARCiA  53  Female   O+     Arthritis  2024-04-02
#
#         Samantha Davies                       Kim Inc          Medicare  \
# 0      Tiffany Mitchell                      Cook PLC             Aetna
# ...

# %%
# TO read particular colums
pd.read_csv("healthcare_dataset.csv",usecols=["Name","Medical Condition"])
# Out:
#                     Name Medical Condition
# 0          Bobby JacksOn            Cancer
# 1           LesLie TErRy           Obesity
# 2            DaNnY sMitH           Obesity
# 3           andrEw waTtS          Diabetes
# 4          adrIENNE bEll            Cancer
# ...                  ...               ...
# 55495  eLIZABeTH jaCkSOn            Asthma
# 55496         KYle pEREz           Obesity
# 55497       HEATher WaNG      Hypertension
# 55498     JENniFER JOneS         Arthritis
# 55499       jAMES GARCiA         Arthritis
#
# [55500 rows x 2 columns]

# %%
# data structure>> We store data in form of series and dataframe
# Series >> 1 Dimensional in nature
# Dataframe >> 2 Dimensional in nature

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#if want to see hospital
df.Hospital
# Out:
# 0                     Sons and Miller
# 1                             Kim Inc
# 2                            Cook PLC
# 3          Hernandez Rogers and Vang,
# 4                         White-White
#                      ...
# 55495                  Jones-Thompson
# 55496                    Tucker-Moyer
# 55497    and Mahoney Johnson Vasquez,
# 55498        Jackson Todd and Castro,
# 55499                  Henry Sons and
# Name: Hospital, Length: 55500, dtype: object

# %%
#Another method to acces colums>> mostly used
df["Hospital"]
# Out:
# 0                     Sons and Miller
# 1                             Kim Inc
# 2                            Cook PLC
# 3          Hernandez Rogers and Vang,
# 4                         White-White
#                      ...
# 55495                  Jones-Thompson
# 55496                    Tucker-Moyer
# 55497    and Mahoney Johnson Vasquez,
# 55498        Jackson Todd and Castro,
# 55499                  Henry Sons and
# Name: Hospital, Length: 55500, dtype: object

# %%
type(df["Hospital"])# a column is a series in a dataframe
# Out:
# pandas.core.series.Series

# %%
l=[1,2,3,4,5]
s=pd.Series(l)#One-dimensional ndarray with axis labels (including time series).

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#by default indexes are integer,we can hav custom indexes
d=pd.Series([100,200,300],index=["Ajay","Prathamesh","Sarvika"])

# %%
d
# Out:
# Ajay          100
# Prathamesh    200
# Sarvika       300
# dtype: int64

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
d["Ajay"]
# Out:
# np.int64(100)

# %%
# To see all the index of a series
d.index
# Out:
# Index(['Ajay', 'Prathamesh', 'Sarvika'], dtype='object')

# %%
# TO reset index
d.reset_index(drop=True)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
d# if you want to convert this seires into data fram
# Out:
# Ajay          100
# Prathamesh    200
# Sarvika       300
# dtype: int64

# %%
pd.DataFrame(d)
# Out:
#               0
# Ajay        100
# Prathamesh  200
# Sarvika     300

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
# If you want ot first 5 rows
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
#If you wan first 3 rows using head
df.head(3)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
#
#              Doctor         Hospital Insurance Provider  Billing Amount  \
# 0     Matthew Smith  Sons and Miller         Blue Cross    18856.281306
# 1   Samantha Davies          Kim Inc           Medicare    33643.327287
# 2  Tiffany Mitchell         Cook PLC              Aetna    27955.096079
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     2024-02-02  Paracetamol        Normal
# 1          265      Emergency     2019-08-26    Ibuprofen  Inconclusive
# 2          205      Emergency     2022-10-07      Aspirin        Normal

# %%
# if you want to see last 5 rows
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
# if you want to see last 2 rows using head
df.tail(2)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 55498  JENniFER JOneS   43    Male         O-         Arthritis
# 55499    jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission          Doctor                  Hospital  \
# 55498        2019-05-25  Kimberly Curry  Jackson Todd and Castro,
# 55499        2024-04-02   Dennis Warren            Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 55498           Medicare    32451.092358          321       Elective
# 55499              Aetna     4010.134172          448         Urgent
#
#       Discharge Date Medication Test Results
# 55498     2019-05-31  Ibuprofen     Abnormal
# 55499     2024-04-29  Ibuprofen     Abnormal

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
#converting columns into list
list(df.columns)
# Out:
# ['Name',
#  'Age',
#  'Gender',
#  'Blood Type',
#  'Medical Condition',
#  'Date of Admission',
#  'Doctor',
#  'Hospital',
#  'Insurance Provider',
#  'Billing Amount',
#  'Room Number',
#  'Admission Type',
#  'Discharge Date',
#  'Medication',
#  'Test Results']

# %%
#If you want to see any random rows
df.sample(4)# pass how muc rows you wan too see
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 30943   THERESa bArRY   23    Male        AB+            Cancer
# 3106   emILY WILLIAMS   28  Female         B+          Diabetes
# 41681  yVOnnE JeNkInS   33    Male         B+         Arthritis
# 52090    ANThoNy HaLL   44    Male        AB-           Obesity
#
#       Date of Admission           Doctor                       Hospital  \
# 30943        2021-04-30     Maria Miller                    Walters Inc
# 3106         2019-12-11  Sharon Campbell                   Howard-Davis
# 41681        2021-03-28     Wendy Sawyer  Stephenson Smith Morales, and
# 52090        2022-08-28    Kaitlyn Terry        and Cain, Phillips Kane
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 30943           Medicare    13018.171576          103      Emergency
# 3106               Aetna    50325.557008          244       Elective
# 41681           Medicare    10646.492318          296       Elective
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
#converting serires to dataframe
s=pd.Series([100,200,300],index=['A','B','C'])

# %%
s
# Out:
# A    100
# B    200
# C    300
# dtype: int64

# %%
d=pd.DataFrame(s)
d
# Out:
#      0
# A  100
# B  200
# C  300

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
#IF you want to add new coulumn in data frame
d["new"]="hello"
d
# Out:
#      0    new
# A  100  hello
# B  200  hello
# C  300  hello

# %%
d["new"]# Best way to access the column this way but if its a continous string you can access df.columnname
# Out:
# A    hello
# B    hello
# C    hello
# Name: new, dtype: object

# %%
d["new2"]=[1,2,3]# no of new column elements should be equsld to no of rows
d
# Out:
#      0    new  new2
# A  100  hello     1
# B  200  hello     2
# C  300  hello     3

# %%
# if you want to change the column name
d.columns=['col1','col2','col3']

# %%
d
# Out:
#    col1   col2  col3
# A   100  hello     1
# B   200  hello     2
# C   300  hello     3

# %%
# Reset index
d.reset_index(drop=True)
# Out:
#    col1   col2  col3
# 0   100  hello     1
# 1   200  hello     2
# 2   300  hello     3

# %%
# acessing one colums
df["Hospital"]
# Out:
# 0                     Sons and Miller
# 1                             Kim Inc
# 2                            Cook PLC
# 3          Hernandez Rogers and Vang,
# 4                         White-White
#                      ...
# 55495                  Jones-Thompson
# 55496                    Tucker-Moyer
# 55497    and Mahoney Johnson Vasquez,
# 55498        Jackson Todd and Castro,
# 55499                  Henry Sons and
# Name: Hospital, Length: 55500, dtype: object

# %%
#Accessing one column -- series,multiple colums (with square bracket becomes a dataframe)
# a subset of dataframe
df_subset=df[["Name","Age","Gender"]]
df_subset
# Out:
#                     Name  Age  Gender
# 0          Bobby JacksOn   30    Male
# 1           LesLie TErRy   62    Male
# 2            DaNnY sMitH   76  Female
# 3           andrEw waTtS   28  Female
# 4          adrIENNE bEll   43  Female
# ...                  ...  ...     ...
# 55495  eLIZABeTH jaCkSOn   42  Female
# 55496         KYle pEREz   61  Female
# 55497       HEATher WaNG   38  Female
# 55498     JENniFER JOneS   43    Male
# 55499       jAMES GARCiA   53  Female
#
# [55500 rows x 3 columns]

# %%
type(df_subset)
# Out:
# pandas.core.frame.DataFrame

# %%
# other file accessing method
# Example --> pd.read_excel("file_name.xlsx")
