# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
 #graph_objects and express
import plotly.graph_objects as go
import plotly.express as px

# %%
# Graph object
# before any graph you should initilise figure
# add_trace>> adding data

fig=go.Figure()
fig.add_trace(x=[1,2,3,4,5],y=[1,7,8,2,6])
