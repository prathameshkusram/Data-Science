# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e53dc934-fe4d-4ef1-b128-3473ed8d5a08">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers

# %%
pip install bokeh_sampledata
# Out:
# Collecting bokeh_sampledata
#   Downloading bokeh_sampledata-2025.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting icalendar (from bokeh_sampledata)
#   Downloading icalendar-6.3.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh_sampledata) (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh_sampledata) (1.17.0)
# Downloading bokeh_sampledata-2025.0-py3-none-any.whl (17.7 MB)
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.7 MB ? eta -:--:--
#    - -------------------------------------- 0.8/17.7 MB 3.9 MB/s eta 0:00:05
#    -- ------------------------------------- 1.3/17.7 MB 2.6 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/17.7 MB 2.0 MB/s eta 0:00:08
#    --- ------------------------------------ 1.6/17.7 MB 2.0 MB/s eta 0:00:08
#    --- ------------------------------------ 1.6/17.7 MB 2.0 MB/s eta 0:00:08
#    --- ------------------------------------ 1.6/17.7 MB 2.0 MB/s eta 0:00:08
#    --- ------------------------------------ 1.6/17.7 MB 2.0 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.1/17.7 MB 1.2 MB/s eta 0:00:13
#    ----- ---------------------------------- 2.4/17.7 MB 1.2 MB/s eta 0:00:13
#    ----- ---------------------------------- 2.6/17.7 MB 1.2 MB/s eta 0:00:13
#    ------- -------------------------------- 3.1/17.7 MB 1.3 MB/s eta 0:00:12
#    -------- ------------------------------- 3.7/17.7 MB 1.4 MB/s eta 0:00:11
#    -------- ------------------------------- 3.9/17.7 MB 1.4 MB/s eta 0:00:10
#    --------- ------------------------------ 4.2/17.7 MB 1.4 MB/s eta 0:00:10
#    --------- ------------------------------ 4.2/17.7 MB 1.4 MB/s eta 0:00:10
#    ---------- ----------------------------- 4.5/17.7 MB 1.3 MB/s eta 0:00:10
#    ---------- ----------------------------- 4.7/17.7 MB 1.3 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.0/17.7 MB 1.3 MB/s eta 0:00:10
#    ----------- ---------------------------- 5.0/17.7 MB 1.3 MB/s eta 0:00:10
#    ------------ --------------------------- 5.5/17.7 MB 1.3 MB/s eta 0:00:10
#    ------------- -------------------------- 5.8/17.7 MB 1.3 MB/s eta 0:00:10
#    ------------- -------------------------- 6.0/17.7 MB 1.3 MB/s eta 0:00:10
#    -------------- ------------------------- 6.3/17.7 MB 1.3 MB/s eta 0:00:09
#    -------------- ------------------------- 6.6/17.7 MB 1.3 MB/s eta 0:00:09
#    --------------- ------------------------ 6.8/17.7 MB 1.3 MB/s eta 0:00:09
#    --------------- ------------------------ 6.8/17.7 MB 1.3 MB/s eta 0:00:09
#    --------------- ------------------------ 7.1/17.7 MB 1.3 MB/s eta 0:00:09
#    ---------------- ----------------------- 7.3/17.7 MB 1.3 MB/s eta 0:00:09
#    ----------------- ---------------------- 7.6/17.7 MB 1.2 MB/s eta 0:00:09
#    ----------------- ---------------------- 7.6/17.7 MB 1.2 MB/s eta 0:00:09
#    ----------------- ---------------------- 7.9/17.7 MB 1.2 MB/s eta 0:00:09
#    ----------------- ---------------------- 7.9/17.7 MB 1.2 MB/s eta 0:00:09
#    ------------------ --------------------- 8.4/17.7 MB 1.2 MB/s eta 0:00:08
#    ------------------ --------------------- 8.4/17.7 MB 1.2 MB/s eta 0:00:08
#    ------------------- -------------------- 8.7/17.7 MB 1.2 MB/s eta 0:00:08
#    -------------------- ------------------- 8.9/17.7 MB 1.2 MB/s eta 0:00:08
#    -------------------- ------------------- 9.2/17.7 MB 1.2 MB/s eta 0:00:08
#    --------------------- ------------------ 9.4/17.7 MB 1.2 MB/s eta 0:00:07
#    --------------------- ------------------ 9.7/17.7 MB 1.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 10.2/17.7 MB 1.2 MB/s eta 0:00:07
#    ----------------------- ---------------- 10.5/17.7 MB 1.2 MB/s eta 0:00:06
#    ------------------------ --------------- 10.7/17.7 MB 1.2 MB/s eta 0:00:06
#    ------------------------ --------------- 10.7/17.7 MB 1.2 MB/s eta 0:00:06
#    ------------------------ --------------- 11.0/17.7 MB 1.2 MB/s eta 0:00:06
#    ------------------------- -------------- 11.3/17.7 MB 1.2 MB/s eta 0:00:06
#    -------------------------- ------------- 11.5/17.7 MB 1.2 MB/s eta 0:00:06
#    -------------------------- ------------- 11.8/17.7 MB 1.2 MB/s eta 0:00:05
#    --------------------------- ------------ 12.1/17.7 MB 1.2 MB/s eta 0:00:05
#    --------------------------- ------------ 12.3/17.7 MB 1.2 MB/s eta 0:00:05
#    ---------------------------- ----------- 12.6/17.7 MB 1.2 MB/s eta 0:00:05
#    ----------------------------- ---------- 12.8/17.7 MB 1.2 MB/s eta 0:00:04
#    ----------------------------- ---------- 13.1/17.7 MB 1.2 MB/s eta 0:00:04
#    ------------------------------ --------- 13.4/17.7 MB 1.2 MB/s eta 0:00:04
#    ------------------------------- -------- 13.9/17.7 MB 1.2 MB/s eta 0:00:04
#    -------------------------------- ------- 14.4/17.7 MB 1.3 MB/s eta 0:00:03
#    --------------------------------- ------ 14.9/17.7 MB 1.3 MB/s eta 0:00:03
#    ---------------------------------- ----- 15.2/17.7 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 15.5/17.7 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 16.3/17.7 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 16.8/17.7 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 17.0/17.7 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 17.7/17.7 MB 1.4 MB/s  0:00:12
# Downloading icalendar-6.3.2-py3-none-any.whl (242 kB)
# Installing collected packages: icalendar, bokeh_sampledata
#
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    ---------------------------------------- 2/2 [bokeh_sampledata]
#
# Successfully installed bokeh_sampledata-2025.0 icalendar-6.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from bokeh.sampledata.iris import flowers
from  bokeh.plotting import figure,output_file,show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p=figure(title='test_flower')
p.xaxis.axis_label='petal_lenght'
p.yaxis.axis_label='petal_width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# Cell In[25], line 6
#       4 p.yaxis.axis_label='petal_width'
#       5 p.circle(flowers['petal_length'],flowers['petal_width'])
# ----> 6 show(p)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:157, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     154 state = curstate()
#     156 if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     159 def is_application(obj: Any) -> TypeGuard[Application]:
#     160     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:204, in _show_with_state(obj, state, browser, new, notebook_handle)
#     202 if state.notebook:
#     203     assert state.notebook_type is not None
# --> 204     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205     shown = True
#     207 if state.file or not shown:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if _HOOKS[notebook_type][action] is None:
#     370     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:603, in show_doc(obj, state, notebook_handle)
#     599 '''
#     600
#     601 '''
#     602 if obj not in state.document.roots:
# --> 603     state.document.add_root(obj)
#     605 from ..embed.notebook import notebook_content
#     606 comms_target = make_id() if notebook_handle else None
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\document.py:331, in Document.add_root(self, model, setter)
#     328 if model in self._roots:
#     329     return
# --> 331 with self.models.freeze():
#     332     self._roots.append(model)
#     334 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:215, in DocumentModelManager.recompute(self)
#     213 new_models: set[Model] = set()
#     214 for mr in document.roots:
# --> 215     new_models |= mr.references()
#     217 old_models = set(self._models.values())
#     219 to_detach = old_models - new_models
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\model.py:492, in Model.references(self)
#     488 def references(self) -> set[Model]:
#     489     ''' Returns all ``Models`` that this object has references to.
#     490
#     491     '''
# --> 492     return set(collect_models(self))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:139, in collect_models(*input_values)
#     123 def collect_models(*input_values: Any) -> list[Model]:
#     124     ''' Collect a duplicate-free list of all other Bokeh models referred to by
#     125     this model, or by any of its references, etc.
#     126
#    (...)    137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:119, in collect_filtered_models(discard, *input_values)
#     117         ids.add(obj.id)
#     118         collected.append(obj)
# --> 119         visit_immediate_value_references(obj, queue_one)
#     121 return collected
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:185, in visit_immediate_value_references(value, visitor)
#     183 if isinstance(value, HasProps):
#     184     for attr in value.properties_with_refs():
# --> 185         child = getattr(value, attr)
#     186         visit_value_and_its_immediate_references(child, visitor)
#     187 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\core\property\descriptors.py:282, in PropertyDescriptor.__get__(self, obj, owner)
#     280     value = self._get(obj)
#     281     if value is Undefined:
# --> 282         raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283     return value
#     285 elif owner is not None:
#
# UnsetValueError: Circle(id='p1151', ...).radius doesn't have a value set

# %%
output_file('test.html')
p=figure(title='test_flower')
p.xaxis.axis_label='petal_lenght'
p.yaxis.axis_label='petal_width'
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# Cell In[26], line 6
#       4 p.yaxis.axis_label='petal_width'
#       5 p.line(flowers['petal_length'],flowers['petal_width'])
# ----> 6 show(p)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:157, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     154 state = curstate()
#     156 if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     159 def is_application(obj: Any) -> TypeGuard[Application]:
#     160     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:204, in _show_with_state(obj, state, browser, new, notebook_handle)
#     202 if state.notebook:
#     203     assert state.notebook_type is not None
# --> 204     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205     shown = True
#     207 if state.file or not shown:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if _HOOKS[notebook_type][action] is None:
#     370     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:603, in show_doc(obj, state, notebook_handle)
#     599 '''
#     600
#     601 '''
#     602 if obj not in state.document.roots:
# --> 603     state.document.add_root(obj)
#     605 from ..embed.notebook import notebook_content
#     606 comms_target = make_id() if notebook_handle else None
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\document.py:331, in Document.add_root(self, model, setter)
#     328 if model in self._roots:
#     329     return
# --> 331 with self.models.freeze():
#     332     self._roots.append(model)
#     334 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:215, in DocumentModelManager.recompute(self)
#     213 new_models: set[Model] = set()
#     214 for mr in document.roots:
# --> 215     new_models |= mr.references()
#     217 old_models = set(self._models.values())
#     219 to_detach = old_models - new_models
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\model.py:492, in Model.references(self)
#     488 def references(self) -> set[Model]:
#     489     ''' Returns all ``Models`` that this object has references to.
#     490
#     491     '''
# --> 492     return set(collect_models(self))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:139, in collect_models(*input_values)
#     123 def collect_models(*input_values: Any) -> list[Model]:
#     124     ''' Collect a duplicate-free list of all other Bokeh models referred to by
#     125     this model, or by any of its references, etc.
#     126
#    (...)    137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:119, in collect_filtered_models(discard, *input_values)
#     117         ids.add(obj.id)
#     118         collected.append(obj)
# --> 119         visit_immediate_value_references(obj, queue_one)
#     121 return collected
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:185, in visit_immediate_value_references(value, visitor)
#     183 if isinstance(value, HasProps):
#     184     for attr in value.properties_with_refs():
# --> 185         child = getattr(value, attr)
#     186         visit_value_and_its_immediate_references(child, visitor)
#     187 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\core\property\descriptors.py:282, in PropertyDescriptor.__get__(self, obj, owner)
#     280     value = self._get(obj)
#     281     if value is Undefined:
# --> 282         raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283     return value
#     285 elif owner is not None:
#
# UnsetValueError: Circle(id='p1151', ...).radius doesn't have a value set

# %%
x=[1,2,3,4]
y=[3,8,4,7]
p=figure(title='line_char')
p.line(x,y)
show(p)
# Out:
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# Cell In[27], line 5
#       3 p=figure(title='line_char')
#       4 p.line(x,y)
# ----> 5 show(p)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:157, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     154 state = curstate()
#     156 if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     159 def is_application(obj: Any) -> TypeGuard[Application]:
#     160     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:204, in _show_with_state(obj, state, browser, new, notebook_handle)
#     202 if state.notebook:
#     203     assert state.notebook_type is not None
# --> 204     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205     shown = True
#     207 if state.file or not shown:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if _HOOKS[notebook_type][action] is None:
#     370     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:603, in show_doc(obj, state, notebook_handle)
#     599 '''
#     600
#     601 '''
#     602 if obj not in state.document.roots:
# --> 603     state.document.add_root(obj)
#     605 from ..embed.notebook import notebook_content
#     606 comms_target = make_id() if notebook_handle else None
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\document.py:331, in Document.add_root(self, model, setter)
#     328 if model in self._roots:
#     329     return
# --> 331 with self.models.freeze():
#     332     self._roots.append(model)
#     334 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:215, in DocumentModelManager.recompute(self)
#     213 new_models: set[Model] = set()
#     214 for mr in document.roots:
# --> 215     new_models |= mr.references()
#     217 old_models = set(self._models.values())
#     219 to_detach = old_models - new_models
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\model.py:492, in Model.references(self)
#     488 def references(self) -> set[Model]:
#     489     ''' Returns all ``Models`` that this object has references to.
#     490
#     491     '''
# --> 492     return set(collect_models(self))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:139, in collect_models(*input_values)
#     123 def collect_models(*input_values: Any) -> list[Model]:
#     124     ''' Collect a duplicate-free list of all other Bokeh models referred to by
#     125     this model, or by any of its references, etc.
#     126
#    (...)    137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:119, in collect_filtered_models(discard, *input_values)
#     117         ids.add(obj.id)
#     118         collected.append(obj)
# --> 119         visit_immediate_value_references(obj, queue_one)
#     121 return collected
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:185, in visit_immediate_value_references(value, visitor)
#     183 if isinstance(value, HasProps):
#     184     for attr in value.properties_with_refs():
# --> 185         child = getattr(value, attr)
#     186         visit_value_and_its_immediate_references(child, visitor)
#     187 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\core\property\descriptors.py:282, in PropertyDescriptor.__get__(self, obj, owner)
#     280     value = self._get(obj)
#     281     if value is Undefined:
# --> 282         raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283     return value
#     285 elif owner is not None:
#
# UnsetValueError: Circle(id='p1151', ...).radius doesn't have a value set

# %%
# Out:
# Requirement already satisfied: bokeh in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (3.8.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (2.15.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (2.4.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (25.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (2.3.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (12.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (6.5.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from bokeh) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\win\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
x=[1,2,3,4]
y=[3,8,4,7]
p=figure(title='line_char')
p.scatter(x,y)
show(p)
# Out:
# ---------------------------------------------------------------------------
# UnsetValueError                           Traceback (most recent call last)
# Cell In[30], line 5
#       3 p=figure(title='line_char')
#       4 p.scatter(x,y)
# ----> 5 show(p)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:157, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     154 state = curstate()
#     156 if isinstance(obj, UIElement) or isinstance(obj, Sequence):
# --> 157     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     159 def is_application(obj: Any) -> TypeGuard[Application]:
#     160     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\showing.py:204, in _show_with_state(obj, state, browser, new, notebook_handle)
#     202 if state.notebook:
#     203     assert state.notebook_type is not None
# --> 204     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     205     shown = True
#     207 if state.file or not shown:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if _HOOKS[notebook_type][action] is None:
#     370     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\io\notebook.py:603, in show_doc(obj, state, notebook_handle)
#     599 '''
#     600
#     601 '''
#     602 if obj not in state.document.roots:
# --> 603     state.document.add_root(obj)
#     605 from ..embed.notebook import notebook_content
#     606 comms_target = make_id() if notebook_handle else None
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\document.py:331, in Document.add_root(self, model, setter)
#     328 if model in self._roots:
#     329     return
# --> 331 with self.models.freeze():
#     332     self._roots.append(model)
#     334 self.callbacks.trigger_on_change(RootAddedEvent(self, model, setter))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:135, in DocumentModelManager.freeze(self)
#     133 self._push_freeze()
#     134 yield
# --> 135 self._pop_freeze()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:288, in DocumentModelManager._pop_freeze(self)
#     286 self._freeze_count -= 1
#     287 if self._freeze_count == 0:
# --> 288     self.recompute()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\document\models.py:215, in DocumentModelManager.recompute(self)
#     213 new_models: set[Model] = set()
#     214 for mr in document.roots:
# --> 215     new_models |= mr.references()
#     217 old_models = set(self._models.values())
#     219 to_detach = old_models - new_models
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\model.py:492, in Model.references(self)
#     488 def references(self) -> set[Model]:
#     489     ''' Returns all ``Models`` that this object has references to.
#     490
#     491     '''
# --> 492     return set(collect_models(self))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:139, in collect_models(*input_values)
#     123 def collect_models(*input_values: Any) -> list[Model]:
#     124     ''' Collect a duplicate-free list of all other Bokeh models referred to by
#     125     this model, or by any of its references, etc.
#     126
#    (...)    137
#     138     '''
# --> 139     return collect_filtered_models(None, *input_values)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:119, in collect_filtered_models(discard, *input_values)
#     117         ids.add(obj.id)
#     118         collected.append(obj)
# --> 119         visit_immediate_value_references(obj, queue_one)
#     121 return collected
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\model\util.py:185, in visit_immediate_value_references(value, visitor)
#     183 if isinstance(value, HasProps):
#     184     for attr in value.properties_with_refs():
# --> 185         child = getattr(value, attr)
#     186         visit_value_and_its_immediate_references(child, visitor)
#     187 else:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\bokeh\core\property\descriptors.py:282, in PropertyDescriptor.__get__(self, obj, owner)
#     280     value = self._get(obj)
#     281     if value is Undefined:
# --> 282         raise UnsetValueError(f"{obj}.{self.name} doesn't have a value set")
#     283     return value
#     285 elif owner is not None:
#
# UnsetValueError: Circle(id='p1151', ...).radius doesn't have a value set
