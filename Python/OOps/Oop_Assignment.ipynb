# %% [raw]
# What is Object-Oriented Programming (OOP)?
# --> object oriented programing (oop) is a programing approach that organizes code around object rather than just function or procedures.
#
# It helps developers model real world thing in code,making programs easier to understand ,reuse,scale and maintain

# %% [raw]
# What is a Class in OOP?
# --> A class is a blueprint or template for creating objects.
#
# It defines >>
# 1] Properties(attributes)->data
# 2]Method(functions)->behavior
#
# Example-->
# class :car
# -->Properties : color,speed
# --> Method : Drive(),brake()

# %% [raw]
# What is an object in oop?
# --> An object is a real instance of a class
# It represents a specific thing created from that blueprint
#
# Example>>
# object1: red car,speed 60
# object2: blue car,speed 40
# Both are object of the car class

# %% [raw]
# What is the difference between abstraction and encapsulation?
# -->
# Abstraction -->Abstraction is about hiding complexity and showing only what the user needs to know.
# Focus :
# -->What an object dose
# -->Not how it does it
# Purpose :
# --> Reduce Complexity
# --> Improve readability and usability
#
# Eample:When you drive a car:
# You use the steering wheel, pedals, and brakes ,You don’t need to know how the engine or gearbox works internally
# 🔧 In programming:
# Achieved using interfaces or abstract classes
#
# Encapsulation-->Encapsulation is about protecting data by bundling it with methods and restricting direct access.
#
# Focus :
# -->How data is accessed and modified
# -->Keeping internal data safe
