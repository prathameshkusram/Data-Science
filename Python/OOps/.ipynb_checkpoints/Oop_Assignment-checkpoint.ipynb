# %% [raw]
# 1]What is object oriented programing?
# --> OOP is a way of writing program by using object,just like real world things.It helps organize code so it is easier to understand reuse and manage

# %% [raw]
# 2]What is a class in oop?
# --> A class is a template or plan used to create objects.It tells what data and actions an object will take

# %% [raw]
# 3] What is an object in oop?
# An object is a real thing created from a class .It contains data and ca perform action

# %% [raw]
# 4]Difference between Abstraction and encapsulation
# -->Abstraction means showinng only the important features and hiding the unnecesary details
#
# Encapsulation means wrapping data and methods togther and protecting the data form outside access
#
# Simple Exmaple -->
#     --> Abstraction : Like a car,you only know how to start and driveiy,not how the engine works indise.
#     -->Encapsulation: The engine details are hidden inside the car and can only be accessed in a safe way.
