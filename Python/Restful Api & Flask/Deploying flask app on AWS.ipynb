# %% [raw]
# Deploying flask app in AWS

# %% [raw]
# AWS Application for Beanstalk
# Steps:
# 1]Go to AWS Management Console:
#     Navigate to the AWS elastic Beanstalk console
# 2]Create a new Application
# CLick create a new Application
# Enter a name for your application(Eg. My-Python-app)
#
# 3]Create a environment
#     Click on create a new environment
#     Choose Web Server environment
#     Choose python as the platform
#     select the environment tier(eg. Single intsance or load balnaced depending on your need)
# 4]Upload your application
# 6]Configure settings(Optional)
