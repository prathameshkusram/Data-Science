# %% [raw]
# Preparing and saving Ml Models
# 1]Pickle(.pkl)->
# Use case: Quick saving /loading of python objects,including models,suitable for small projects or prototypig
#
# 2]joblib(.joblib)
# Use Case : optimized for large numpy arrrays commonly used in scikit-learn
#
# 3]ONNNX(.onnx)
# ->Use case: Model portability across frameworks like pytorch tensor flow and scikit-learn
#
# 5]savedmodel(.pb or directory structure)
# use case -> Tensorflow models,native support for tensorfloww serving
#
# 6]HDFS(.h5)
# ->Use case: Storing keras models,lightweight format for easy storage
#
# 7]TorchScript(.pt or .pth)
# ->Saving Pytorch models for inference or retraining
#
# 8]PMML(Predective Model Markup Language)
# -> Interoperable format for sharing models between system
#
# 9]BentoML
# ->Packageing models for deployment as REST APIs
#
# 10]JSON
# ->Lightweight models,configuration files,or tree based model
#
# 11]Docker Container
# -> Packageing the entire model and runtime environment
#
# 12] TF Lite
# -> Tensor FLow models on mobile or embedded devices
#
# 13]mlflow
# ->Model versioning ,experiment tracking and deployment.

# %% [raw]
# how to load pretrained models in flask app
#
# 1] Prepare the model
# 2]Set up Flask Application
# 3]Create API endpoint
# 4]Dependency Management
# 5]Testing
# 6]Deployment

# %% [raw]
# Setting up model Inference in Production
#
# General Architecture
# 1]Input Validation Layer: Ensure the input data is sanitized and meets expected requirements
#
# 2] preprocessing Layer: Transform input data intoa format compatible with the model
#
# 3]Inference layer: Load the model and generate prediciton
#
# 4]PostProcessing Layer: Format the predicitons for the response
#
# 5] Logging and monitoring : Log requests and responses for debugging and monitoring performance
#
# 6] Security Measures: Protect the API with authentication ,rate limiting,and secure transport

# %% [raw]
# Setting up model Inference
# Best Practice
#
# 1]Input validation
# 2]Error Handling
# 3]Concurrency
# 4]Model Versioning
# 5]Security
# 6]Monitoring

# %% [raw]
# Setting up model Inference
#
# 1]Real time prediction
# ->Low Latency prediction for user facing application like chatbots recommendation engines or fraud detection
#
# 2]Batch prediction
# ->Prediciting for large dataset,such as daily analytics or bulk data processing
#
# 3]Scheduled Batch Prediction
# ->Periodic processing of data ,such as generating nightly reports or model retraning

# %% [raw]
# Handling Input Data for prediction
# 1]Formating Input Data
# 2]Validating Input data
# 3]Pydantic
# 4]Marshmallow

# %% [raw]
# Dir name => PIMA
