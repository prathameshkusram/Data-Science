# %% [raw]
# Blogging Website using Flask

# %% [raw]
# Commands
# 1]mkdir projects
# 2]cd projects
# 3]git clone https://github.com/nikita9064/Blogging-Website-using-Flask.git
# 4]cd Blogging-Website--using-Flask
# 5]code start .

# %% [raw]
# Making new directory
# In projects only
# Commands->
# 1]mkdir Deployment-In-Render
# 2]cd Deployment-In-Render
# Before starting the code copy the content of Blogging in Deployment-In-Render

# %%
Add on requirenments
1]>pip install gunicorn
2]
