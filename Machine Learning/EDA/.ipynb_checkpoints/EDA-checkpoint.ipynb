# %% [raw]
# EDA - Exploratory Data Analysis
#
# CRISP - DM
# Cross Industry Standard process for Data Mining

# %% [raw]
# 1] Business Understanding -> Exploratory Data Analysis
# 2] Data Understanding -> Missing Value Treatment ,Data Encoding, Outlier detection
# 3]Modeling -> ML alogorithms
# 4] Evaluation
# 5]Deployment

# %% [raw]
# Journy of DS Project
# 1] Data Ingestion (.csv,.tsv.xlsx)
# 2]Exploratory Data Analysis
# 3]Data Preparation / Feature Engineering
# 4] Model Building
# 5] Model Evalution

# %%
EDA  - >
1] Profile Of data ->
    Number of rows,columns ,data Type Duplicate
2]
