# %% [raw]
# Interpolation (Hindi + English):
#
# Interpolation ka matlab: known data points ke beech ke unknown values ko estimate karna
# It is used to find missing values between two known points
#
# 👉 Types (प्रकार):
#
# Linear interpolation
# Polynomial interpolation
#
# 👉 Uses (उपयोग):
#
# Missing data fill karna
# Smooth graph/curve banana
# ML mein (jaise SMOTE), new synthetic data points create karne ke liye
#
# 👉 Simple line:
# "Known values ke beech ka missing value nikalna = Interpolation"

# %% [raw]
# # data Interploation >> is a process of estimating unkown values from the known valyes
#
# Types:
#     1] Linear interpolation
#     2] Cublic interpolation
#     3] Polynomial Interpolation

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([1,2,3,4,5])
y=np.array([1,3,5,7,9])

plt.scatter(x,y)

# %%
# 1 ] Using linear interpolation >> Linear in nature
x_new=np.linspace(1,5,10) #create new X values
y_interp=np.interp(x_new,x,y)

# %%
y_interp
# Out:
# array([1.        , 1.88888889, 2.77777778, 3.66666667, 4.55555556,
#        5.44444444, 6.33333333, 7.22222222, 8.11111111, 9.        ])

# %%
plt.scatter(x_new,y_interp)

# %%
# 2} Cubic interpolation 
x=np.array([1,2,3,4,5])
y=np.array([1,8,27,64,125])

plt.scatter(x,y)

# %% [raw]
# SciPy (Hindi + English notes):
#
# SciPy kya hai: Python library for scientific & technical computing
# Built on NumPy
#
# 👉 Main uses (उपयोग):
#
# Mathematics (math functions)
# Optimization
# Integration
# Interpolation
# Signal processing
# Statistics
#
# 👉 Important modules:
#
# scipy.optimize → optimization problems
# scipy.integrate → integration
# scipy.interpolate → interpolation
# scipy.stats → statistics

# %%
from scipy.interpolate import interp1d
f=interp1d (x,y,kind='cubic')

# %%
f

# %%
x_new=np.linspace(1,5,10)
y_interp=f(x_new)

# %%
y_interp
# Out:
# array([  1.        ,   3.01371742,   6.739369  ,  12.7037037 ,
#         21.43347051,  33.45541838,  49.2962963 ,  69.48285322,
#         94.54183813, 125.        ])

# %%
plt.scatter(x_new,y_interp)

# %%
# 3} Polynomial interpolation
x=np.array([1,2,3,4,5])
y=np.array([1,4,9,1,25])

p=np.polyfit(x,y,2)

# %%
x_new=np.linspace(x,y,10)
y_interp=np.polyval(p,x_new)

# %%
plt.scatter(x,y)

# %%
plt.scatter(x_new,y_interp)

# %% [raw]
# # Use case :
# Missing data, generation of new data point
