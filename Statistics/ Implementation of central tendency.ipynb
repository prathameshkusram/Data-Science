# %%
# mean
age=[28,56,35,76,89]

# %%
import numpy as np
np.mean(age)
# Out:
# np.float64(56.8)

# %%
height=[170,180,100,120,122]
np.mean(height)
# Out:
# np.float64(138.4)

# %%
# Median
nos=[4,2,3,7,8]
np.median(nos)
# Out:
# np.float64(4.0)

# %%
# for mode You have to import Scipy from stats

nos=[4,2,3,7,4,8]
from scipy import stats
stats.mode(nos)
# Out:
# ModeResult(mode=np.int64(4), count=np.int64(2))

# %%
# anothe method 
import statistics as stat
stat.mode(nos)
# Out:
# 4

# %%
# let see how mean is affected by outlier here 1800 is outlier

height=[170,1800,100,120,122]
np.mean(height)
# Out:
# np.float64(462.4)

# %%
np.median(height)
# Out:
# np.float64(122.0)

# %%
height=[150,160,180,175,165]
np.mean(height)
# Out:
# np.float64(166.0)

# %%
height=[150,160,180,175,165]
np.median(height)
# Out:
# np.float64(165.0)

# %%
height=[150,1500,160,180,175,165]
np.mean(height)
# Out:
# np.float64(388.3333333333333)

# %%
height=[150,1500,160,180,175,165]
np.median(height)
# Out:
# np.float64(170.0)
